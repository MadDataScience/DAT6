# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from sklearn.cross_validation import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report

# %%
data = pd.read_csv('https://dl.dropboxusercontent.com/u/5743203/data/titanic/titanic_train.csv')
#data = pd.read_csv('datasets/titanic-train.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                             Heikkinen, Miss. Laina  female   26      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                           Allen, Mr. William Henry    male   35      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
#
# [5 rows x 12 columns]

# %% [markdown]
# ## Question 1:
# Several passengers are missing data points for age. Impute the missing values so that there are no “NaN” values for age as inputs to your model. Explain what value or values you used for the missing age data and why you used those values. (Hint: Think statistically here. Explain your thinking and choices.)

# %% [markdown]
# From the previous exercises we know that Sex and PClass are important feature in predicting survival. Let's double check that.

# %%
len(data)
# Out:
# 891

# %%
data.Age.dtype
# Out:
# dtype('float64')

# %%
features = data[data.columns[5:6]]
features.head()
# Out:
#    Age
# 0   22
# 1   38
# 2   26
# 3   35
# 4   35
#
# [5 rows x 1 columns]

# %%
features.count()
# Out:
# Age    714
# dtype: int64

# %%
median_features = features.dropna().mean()
median_features
# Out:
# Age    29.699118
# dtype: float64

# %%
imputed_features = features.fillna(median_features)
imputed_features.count()
# Out:
# Age    891
# dtype: int64

# %%
features_array = imputed_features.values
features_array
# Out:
# array([[ 22.        ],
#        [ 38.        ],
#        [ 26.        ],
#        [ 35.        ],
#        [ 35.        ],
#        [ 29.69911765],
#        [ 54.        ],
#        [  2.        ],
#        [ 27.        ],
#        [ 14.        ],
#        [  4.        ],
#        [ 58.        ],
#        [ 20.        ],
#        [ 39.        ],
#        [ 14.        ],
#        [ 55.        ],
#        [  2.        ],
#        [ 29.69911765],
#        [ 31.        ],
#        [ 29.69911765],
#        [ 35.        ],
#        [ 34.        ],
#        [ 15.        ],
#        [ 28.        ],
#        [  8.        ],
#        [ 38.        ],
#        [ 29.69911765],
#        [ 19.        ],
#        [ 29.69911765],
#        [ 29.69911765],
#        [ 40.        ],
#        [ 29.69911765],
#        [ 29.69911765],
#        [ 66.        ],
#        [ 28.        ],
#        [ 42.        ],
#        [ 29.69911765],
#        [ 21.        ],
#        [ 18.        ],
#        [ 14.        ],
#        [ 40.        ],
#        [ 27.        ],
#        [ 29.69911765],
#        [  3.        ],
#        [ 19.        ],
#        [ 29.69911765],
#        [ 29.69911765],
#        [ 29.69911765],
#        [ 29.69911765],
#        [ 18.        ],
#        [  7.        ],
#        [ 21.        ],
#        [ 49.        ],
#        [ 29.        ],
#        [ 65.        ],
#        [ 29.69911765],
#        [ 21.        ],
#        [ 28.5       ],
#        [  5.        ],
#        [ 11.        ],
#        [ 22.        ],
#        [ 38.        ],
#        [ 45.        ],
#        [  4.        ],
#        [ 29.69911765],
#        [ 29.69911765],
#        [ 29.        ],
#        [ 19.        ],
#        [ 17.        ],
#        [ 26.        ],
#        [ 32.        ],
#        [ 16.        ],
#        [ 21.        ],
#        [ 26.        ],
#        [ 32.        ],
#        [ 25.        ],
#        [ 29.69911765],
#        [ 29.69911765],
#        [  0.83      ],
#        [ 30.        ],
#        [ 22.        ],
#        [ 29.        ],
#        [ 29.69911765],
#        [ 28.        ],
#        [ 17.        ],
#        [ 33.        ],
#        [ 16.        ],
#        [ 29.69911765],
#        [ 23.        ],
#        [ 24.        ],
#        [ 29.        ],
#        [ 20.        ],
#        [ 46.        ],
#        [ 26.        ],
#        [ 59.        ],
#        [ 29.69911765],
#        [ 71.        ],
#        [ 23.        ],
#        [ 34.        ],
#        [ 34.        ],
#        [ 28.        ],
#        [ 29.69911765],
#        [ 21.        ],
#        [ 33.        ],
#        [ 37.        ],
#        [ 28.        ],
#        [ 21.        ],
#        [ 29.69911765],
#        [ 38.        ],
#        [ 29.69911765],
#        [ 47.        ],
#        [ 14.5       ],
#        [ 22.        ],
#        [ 20.        ],
#        [ 17.        ],
#        [ 21.        ],
#        [ 70.5       ],
#        [ 29.        ],
#        [ 24.        ],
#        [  2.        ],
#        [ 21.        ],
#        [ 29.69911765],
#        [ 32.5       ],
#        [ 32.5       ],
#        [ 54.        ],
#        [ 12.        ],
#        [ 29.69911765],
#        [ 24.        ],
#        [ 29.69911765],
#        [ 45.        ],
#        [ 33.        ],
#        [ 20.        ],
#        [ 47.        ],
#        [ 29.        ],
#        [ 25.        ],
#        [ 23.        ],
#        [ 19.        ],
#        [ 37.        ],
#        [ 16.        ],
#        [ 24.        ],
#        [ 29.69911765],
#        [ 22.        ],
#        [ 24.        ],
#        [ 19.        ],
#        [ 18.        ],
#        [ 19.        ],
#        [ 27.        ],
#        [  9.        ],
#        [ 36.5       ],
#        [ 42.        ],
#        [ 51.        ],
#        [ 22.        ],
#        [ 55.5       ],
#        [ 40.5       ],
#        [ 29.69911765],
#        [ 51.        ],
#        [ 16.        ],
#        [ 30.        ],
#        [ 29.69911765],
#        [ 29.69911765],
#        [ 44.        ],
#        [ 40.        ],
#        [ 26.        ],
#        [ 17.        ],
#        [  1.        ],
#        [  9.        ],
#        [ 29.69911765],
#        [ 45.        ],
#        [ 29.69911765],
#        [ 28.        ],
#        [ 61.        ],
#        [  4.        ],
#        [  1.        ],
#        [ 21.        ],
#        [ 56.        ],
#        [ 18.        ],
#        [ 29.69911765],
#        [ 50.        ],
#        [ 30.        ],
#        [ 36.        ],
#        [ 29.69911765],
#        [ 29.69911765],
#        [  9.        ],
#        [  1.        ],
#        [  4.        ],
#        [ 29.69911765],
#        [ 29.69911765],
#        [ 45.        ],
#        [ 40.        ],
#        [ 36.        ],
#        [ 32.        ],
#        [ 19.        ],
#        [ 19.        ],
#        [  3.        ],
#        [ 44.        ],
#        [ 58.        ],
#        [ 29.69911765],
#        [ 42.        ],
#        [ 29.69911765],
#        [ 24.        ],
#        [ 28.        ],
#        [ 29.69911765],
#        [ 34.        ],
#        [ 45.5       ],
#        [ 18.        ],
#        [  2.        ],
#        [ 32.        ],
#        [ 26.        ],
#        [ 16.        ],
#        [ 40.        ],
#        [ 24.        ],
#        [ 35.        ],
#        [ 22.        ],
#        [ 30.        ],
#        [ 29.69911765],
#        [ 31.        ],
#        [ 27.        ],
#        [ 19.        ],
#        [ 29.69911765],
#        [ 56.        ],
#        [ 25.        ],
#        [ 33.        ],
#        [ 22.        ],
#        [ 28.        ],
#        [ 25.        ],
#        [ 39.        ],
#        [ 27.        ],
#        [ 19.        ],
#        [ 29.69911765],
#        [ 26.        ],
#        [ 32.        ]])

# %%
grouped_by_age_pclass = data.groupby(['Sex', 'Pclass']).mean()
grouped_by_age_pclass
# Out:
#                PassengerId  Survived        Age     SibSp     Parch  \
# Sex    Pclass
# female 1        469.212766  0.968085  34.611765  0.553191  0.457447
#        2        443.105263  0.921053  28.722973  0.486842  0.605263
#        3        399.729167  0.500000  21.750000  0.895833  0.798611
# male   1        455.729508  0.368852  41.281386  0.311475  0.278689
#        2        447.962963  0.157407  30.740707  0.342593  0.222222
#        3        455.515850  0.135447  26.507589  0.498559  0.224784
#
#                      Fare
# Sex    Pclass
# female 1       106.125798
#        2        21.970121
#        3        16.118810
# male   1        67.226127
#        2        19.741782
#        3        12.661633
#
# [6 rows x 6 columns]

# %%
grouped_by_age_pclass.Survived.round(3)*100
# Out:
# Sex     Pclass
# female  1         96.8
#         2         92.1
#         3         50.0
# male    1         36.9
#         2         15.7
#         3         13.5
# Name: Survived, dtype: float64

# %%
# Plot distribution of passenger ages
plt.hist(data[data.Sex == 'male']['Age'].dropna().values, bins=16, range=(0,80), alpha = .3, label='male', normed = True)
plt.hist(data[data.Sex == 'female']['Age'].dropna().values, bins=16, range=(0,80), alpha = .3, label='female', normed = True)
plt.ylabel('Count')
plt.xlabel('Age')
plt.title('Histogram of Passenger Ages')
plt.legend(loc= 'best')
plt.show()

# %%
data.fillna(grouped_by_age_pclass, inplace=True)

# %%
#double check: So, Age have the same amount of inpit value as all other variables "891"
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            891 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                             Heikkinen, Miss. Laina  female   26      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                           Allen, Mr. William Henry    male   35      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
#
# [5 rows x 12 columns]

# %% [markdown]
# ## Question 2:
# Create and run a logistic regression on the Titanic data to predict the survival of passengers.
#
# a. Make sure your model results are reproducible by the instructor team, given any random aspects to your code / steps.
#
# b. For your model output, include coefficient values, residuals, and standard errors.
#
# c. Explain which features are predictive for this logistic regression and, intuitively, why you think this may be so. Describe your thinking / logic in words. It is not sufficient to cite output statistics.
#
# d. Make sure that you can push new data points through your model to get regression output. We will be providing a test set for this purpose.

# %%
import pandas as pd
import statsmodels.api as sm
import pylab as pl
import numpy as np

# %%
dummy_sex =  pd.get_dummies(data['Sex'],)
dummy_sex
# Out:
#     female  male
# 0        0     1
# 1        1     0
# 2        1     0
# 3        1     0
# 4        0     1
# 5        0     1
# 6        0     1
# 7        0     1
# 8        1     0
# 9        1     0
# 10       1     0
# 11       1     0
# 12       0     1
# 13       0     1
# 14       1     0
# 15       1     0
# 16       0     1
# 17       0     1
# 18       1     0
# 19       1     0
# 20       0     1
# 21       0     1
# 22       1     0
# 23       0     1
# 24       1     0
# 25       1     0
# 26       0     1
# 27       0     1
# 28       1     0
# 29       0     1
# 30       0     1
# 31       1     0
# 32       1     0
# 33       0     1
# 34       0     1
# 35       0     1
# 36       0     1
# 37       0     1
# 38       1     0
# 39       1     0
# 40       1     0
# 41       1     0
# 42       0     1
# 43       1     0
# 44       1     0
# 45       0     1
# 46       0     1
# 47       1     0
# 48       0     1
# 49       1     0
# 50       0     1
# 51       0     1
# 52       1     0
# 53       1     0
# 54       0     1
# 55       0     1
# 56       1     0
# 57       0     1
# 58       1     0
# 59       0     1
#        ...   ...
#
# [891 rows x 2 columns]

# %%
dummy_embarked = pd.get_dummies(data['Embarked'], prefix='Embarked')
print dummy_embarked.head()
# Out:
#    Embarked_C  Embarked_Q  Embarked_S
# 0           0           0           1
# 1           1           0           0
# 2           0           0           1
# 3           0           0           1
# 4           0           0           1
#
# [5 rows x 3 columns]

# %%
use_cols = ['Survived', 'Age', 'SibSp', 'Parch', 'Fare']

#data = df[cols_to_keep].join(dummy_ranks.ix[:, 'prestige_2':])

# %%
data_select = data[use_cols].join(dummy_sex.ix[:, 'female']).join(dummy_embarked.ix[:,'Embarked_Q':])

# %%
print data_select.head()
# Out:
#    Survived  Age  SibSp  Parch     Fare  female  Embarked_Q  Embarked_S
# 0         0   22      1      0   7.2500       0           0           1
# 1         1   38      1      0  71.2833       1           0           0
# 2         1   26      0      0   7.9250       1           0           1
# 3         1   35      1      0  53.1000       1           0           1
# 4         0   35      0      0   8.0500       0           0           1
#
# [5 rows x 8 columns]

# %%
print data_select.dtypes
# Out:
# Survived        int64
# Age           float64
# SibSp           int64
# Parch           int64
# Fare          float64
# female        float64
# Embarked_Q    float64
# Embarked_S    float64
# dtype: object

# %%
data_select.count()
# Out:
# Survived      891
# Age           891
# SibSp         891
# Parch         891
# Fare          891
# female        891
# Embarked_Q    891
# Embarked_S    891
# dtype: int64

# %%
data_select.columns[1:]
# Out:
# Index([u'Age', u'SibSp', u'Parch', u'Fare', u'female', u'Embarked_Q', u'Embarked_S'], dtype='object')

# %%
train_cols = data_select.columns[1:]

# %%
logit = sm.Logit(data_select["Survived"], data_select[train_cols])

# %%
results=logit.fit()
results.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.480571
#          Iterations 6
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:               Survived   No. Observations:                  891
# Model:                          Logit   Df Residuals:                      884
# Method:                           MLE   Df Model:                            6
# Date:                Fri, 23 May 2014   Pseudo R-squ.:                  0.2783
# Time:                        20:34:10   Log-Likelihood:                -428.19
# converged:                       True   LL-Null:                       -593.33
#                                         LLR p-value:                 2.638e-68
# ==============================================================================
#                  coef    std err          z      P>|z|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Age           -0.0233      0.005     -5.025      0.000        -0.032    -0.014
# SibSp         -0.3936      0.103     -3.812      0.000        -0.596    -0.191
# Parch         -0.2315      0.115     -2.017      0.044        -0.456    -0.007
# Fare           0.0123      0.003      4.594      0.000         0.007     0.017
# female         2.5769      0.190     13.530      0.000         2.204     2.950
# Embarked_Q    -1.0714      0.331     -3.235      0.001        -1.721    -0.422
# Embarked_S    -0.9802      0.167     -5.861      0.000        -1.308    -0.652
# ==============================================================================
# """
