# %% [markdown]
# You are provided with historical sales data for 45 Walmart stores located in different regions. Each store contains many departments, and participants must project the sales for each department in each store. To add to the challenge, selected holiday markdown events are included in the dataset. These markdowns are known to affect sales, but it is challenging to predict which departments are affected and the extent of the impact.

# %% [markdown]
# For convenience, the four holidays fall within the following weeks in the dataset (not all holidays are in the data):
#
# Super Bowl: 12-Feb-10, 11-Feb-11, 10-Feb-12, 8-Feb-13
# Labor Day: 10-Sep-10, 9-Sep-11, 7-Sep-12, 6-Sep-13
# Thanksgiving: 26-Nov-10, 25-Nov-11, 23-Nov-12, 29-Nov-13
# Christmas: 31-Dec-10, 30-Dec-11, 28-Dec-12, 27-Dec-13

# %%
import pandas as pd

# %%
# !pwd
# Out:
# /Users/t_sutinee/dat6_TS

# %%
WM_features = pd.read_csv("/Users/t_sutinee/dat6_TS/wal-mart/features.csv")
WM_test = pd.read_csv("/Users/t_sutinee/dat6_TS/wal-mart/test.csv")
WM_train = pd.read_csv("/Users/t_sutinee/dat6_TS/wal-mart/train.csv")
WM_stores = pd.read_csv("/Users/t_sutinee/dat6_TS/wal-mart/stores.csv")
WM_sample_sub = pd.read_csv("/Users/t_sutinee/dat6_TS/wal-mart/sampleSubmission.csv")

# %%
WM_features.head()
# Out:
#    Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0      1  2010-02-05        42.31       2.572        NaN        NaN
# 1      1  2010-02-12        38.51       2.548        NaN        NaN
# 2      1  2010-02-19        39.93       2.514        NaN        NaN
# 3      1  2010-02-26        46.63       2.561        NaN        NaN
# 4      1  2010-03-05        46.50       2.625        NaN        NaN
#
#    MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment IsHoliday
# 0        NaN        NaN        NaN  211.096358         8.106     False
# 1        NaN        NaN        NaN  211.242170         8.106      True
# 2        NaN        NaN        NaN  211.289143         8.106     False
# 3        NaN        NaN        NaN  211.319643         8.106     False
# 4        NaN        NaN        NaN  211.350143         8.106     False
#
# [5 rows x 12 columns]

# %%
WM_test.head()
# Out:
#    Store  Dept        Date IsHoliday
# 0      1     1  2012-11-02     False
# 1      1     1  2012-11-09     False
# 2      1     1  2012-11-16     False
# 3      1     1  2012-11-23      True
# 4      1     1  2012-11-30     False
#
# [5 rows x 4 columns]

# %%
WM_train.head()
# Out:
#    Store  Dept        Date  Weekly_Sales IsHoliday
# 0      1     1  2010-02-05      24924.50     False
# 1      1     1  2010-02-12      46039.49      True
# 2      1     1  2010-02-19      41595.55     False
# 3      1     1  2010-02-26      19403.54     False
# 4      1     1  2010-03-05      21827.90     False
#
# [5 rows x 5 columns]

# %%
WM_stores.head()
# Out:
#    Store Type    Size
# 0      1    A  151315
# 1      2    A  202307
# 2      3    B   37392
# 3      4    A  205863
# 4      5    B   34875
#
# [5 rows x 3 columns]

# %%
WM_sample_sub.head()
# Out:
#                Id  Weekly_Sales
# 0  1_1_2012-11-02             0
# 1  1_1_2012-11-09             0
# 2  1_1_2012-11-16             0
# 3  1_1_2012-11-23             0
# 4  1_1_2012-11-30             0
#
# [5 rows x 2 columns]

# %%
c = MongoClient()
db = c.
# Out:
#   File "<ipython-input-9-eaec674ea993>", line 2
#     db = c.
#            ^
# SyntaxError: invalid syntax
